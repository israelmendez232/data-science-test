# %% [markdown]
# # Teste de Cientista de Dados
# Configurações do teste primeiro
#
# ---
#
# ### Entendendo os Dados
# Primeiro, vamos analisar os formatos que temos e informações principais de cada tabela. Sabendo de temos valores nulos e tendo uma noção das colunas com seus respectivos tipos.

# %%
# CONFIG
from sqlalchemy import create_engine
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

engine = create_engine('sqlite:////home/israel/Coisas/Codigo/data-science-test/container/dsci_test.sqlite')

# %% [markdown]
# #### Tabela Itens
# Ententendo cada tabela por vez, começando com a tabela de Itens.

# %%
df_itens = pd.read_sql('select * from itens', engine)

df_itens.head()
# Out:
#                 codigo_produto_mask                 setor    familia  \
# 0  66947358462228cf9b31cafc6368174f             Alimentos  Cachorros
# 1  97f1357808314f0979f32f06c1b02e01  Medicina e Bem Estar  Cachorros
# 2  5a4a1c97b398d291f11aeeb178f05862            Brinquedos  Cachorros
# 3  321bbe12a625bf8217baa30ffdd2fc7b  Medicina e Bem Estar  Cachorros
# 4  8c65837857523fe7d4faf12c2c4c04ae             Alimentos  Cachorros
#
#                 subfamilia  peso_unitario
# 0                 Bifinhos          0.520
# 1  Vitaminas e Suplementos          0.050
# 2                  Objetos          0.073
# 3  Antipulgas e Carrapatos          0.100
# 4              Ração Úmida          0.100

# %% [markdown]
# Entendendo melhor agora o tamanho do Dataframe, colunas, se apresenta algum valor nulo e outros:

# %%
df_itens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11521 entries, 0 to 11520
# Data columns (total 5 columns):
# codigo_produto_mask    11521 non-null object
# setor                  11521 non-null object
# familia                11521 non-null object
# subfamilia             11521 non-null object
# peso_unitario          11521 non-null float64
# dtypes: float64(1), object(4)
# memory usage: 450.2+ KB

# %% [markdown]
# Por fim, avaliando o básico de estatística nas colunas numéricas:

# %%
df_itens.describe()
# Out:
#        peso_unitario
# count   11521.000000
# mean        1.739357
# std         3.867471
# min         0.005000
# 25%         0.088000
# 50%         0.240000
# 75%         1.027000
# max        30.250000

# %% [markdown]
# #### Tabela Pedidos
# Ententendo agora a tabela de pedidos, vendo o DF em partes, depois pensando nos detalhes por coluna e vendo o básico estatístico de colunas numéricas.

# %%
df_orders = pd.read_sql('select * from pedidos limit 100', engine)
df_orders.head()
# Out:
#                      id_pedido_mask  pedido_assinatura  contagempedidos  \
# 0  c5c58805a8d84c9de5b43644f83406c9                  0                1
# 1  cf66924d6e2d3ee59d23687ffbf6503a                  0                5
# 2  fc955ecdb43129249918f7df5bb30fa2                  0                8
# 3  38b5b3fed9097a193006d6d9acde05ed                  1               13
# 4  00c6dca9fbed874f07b97b6211e73094                  0                6
#
#                         canal_venda                    subcanal_venda  \
# 0  15bbb9d0bbf25e8d2978de1168c749dc  532c28d5412dd75bf975fb951c740a30
# 1  15bbb9d0bbf25e8d2978de1168c749dc  b2c79ad7dcf03ba266dc0885e1266675
# 2  15bbb9d0bbf25e8d2978de1168c749dc  532c28d5412dd75bf975fb951c740a30
# 3  a564de63c2d0da68cf47586ee05984d7  6ab241effd5d8dd6ecdd79cba1ac174a
# 4  15bbb9d0bbf25e8d2978de1168c749dc  532c28d5412dd75bf975fb951c740a30
#
#                     canal_marketing          forma_pagamento  parcelas
# 0  47a6f6bcb1457a3123e24eada0ca981f  Cartão de Crédito Total         3
# 1  6e9790f4d0acd2721e0b370023de531d  Cartão de Crédito Total         2
# 2  eb6945d3ad790ec60e20c6c85a54e30b                   Boleto         1
# 3  decc1eab6d0751fcb2d8e41a2ffeb55a  Cartão de Crédito Total         2
# 4  5577d244b0e0f090fb16401226bfd8e4  Cartão de Crédito Total         2

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
# id_pedido_mask       100 non-null object
# pedido_assinatura    100 non-null int64
# contagempedidos      100 non-null int64
# canal_venda          100 non-null object
# subcanal_venda       100 non-null object
# canal_marketing      100 non-null object
# forma_pagamento      100 non-null object
# parcelas             100 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 6.4+ KB

# %%
df_orders.describe()
# Out:
#        pedido_assinatura  contagempedidos    parcelas
# count         100.000000       100.000000  100.000000
# mean            0.410000         9.760000    2.230000
# std             0.494311        14.623297    1.003579
# min             0.000000         1.000000    1.000000
# 25%             0.000000         1.000000    1.000000
# 50%             0.000000         4.000000    2.500000
# 75%             1.000000        11.250000    3.000000
# max             1.000000        91.000000    6.000000

# %% [markdown]
# #### Tabela Transações
# Ententendo um pouco mais agora da tabela de transacoes.

# %%
df_transactions = pd.read_sql('select * from transacoes limit 100', engine)
df_transactions.head()
# Out:
#                      id_pedido_mask                   id_usuario_mask  \
# 0  1b36ebea2c986781b5a7500b7d8971a5  57c9bb7ce32a4629b791c11f113f4e08
# 1  e303a604a1d1cd5b7455dcaf256da2ec  e99abed19b0ede9a1768de5af9573a70
# 2  830172ec53b00a9feeefce2465eafe4c  309ba5b53dce34cac24a37b196e51c76
# 3  a46ca254a2cf132f8c2087e825cc46e4  8e3428b0da37721f59d06b648fdb1d69
# 4  00627c9841286f7a2054a6b3b54d05dd  874af7ab886dd5ad7c8306d0c2f6ac83
#
#                 codigo_produto_mask  quantidade  receita  frete  desconto  \
# 0  b56aa30a87fa7812daa689886060c0b9           1    33.66   0.00      3.74
# 1  9322504cb6521dddcf8fcca18810c975           1     0.00   0.00     99.90
# 2  cca7873258ccf037fee3ee6077a67a97           1   269.09   0.00     29.90
# 3  db69799b4b02e6d708fdf6408b400a0e           1   161.50   0.00      0.00
# 4  97f1357808314f0979f32f06c1b02e01           1    41.37   0.96      4.49
#
#    brinde
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0

# %%
df_transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
# id_pedido_mask         100 non-null object
# id_usuario_mask        100 non-null object
# codigo_produto_mask    100 non-null object
# quantidade             100 non-null int64
# receita                100 non-null float64
# frete                  100 non-null float64
# desconto               100 non-null float64
# brinde                 100 non-null int64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 6.4+ KB

# %%
df_transactions.describe()
# Out:
#        quantidade     receita       frete    desconto      brinde
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     3.480000   74.930000    1.128800    9.088200    0.090000
# std      8.758811   76.710813    3.596698   15.971051    0.287623
# min      1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   12.727500    0.000000    0.000000    0.000000
# 50%      1.000000   53.250000    0.000000    2.475000    0.000000
# 75%      1.250000  114.327500    0.007500   11.160000    0.000000
# max     55.000000  392.040000   28.070000   99.900000    1.000000

# %% [markdown]
# ---
#
# ## Etapa 1: Análise Exploratória
# Agora, entendendo os dados e tirando insights.
#
# Tendo em vista que as tabelas são pequenas (no máx. 450kb), vou juntar todas em um dataframe só para ficar mais fácil de analisar todas as informações.

# %%
# # TRANSFORMANDO AS COLUNS DE JOIN EM STRING ESPECÍFICOS
# df_transactions['id_pedido_mask'] = df_transactions['id_pedido_mask'].str.strip()
# df_orders['id_pedido_mask'] = df_orders['id_pedido_mask'].str.strip()

# # # df_transactions['codigo_produto_mask'] = df_transactions['codigo_produto_mask'].str.encode('utf-8')
# # # df_itens['codigo_produto_mask'] = df_orders['codigo_produto_mask'].str.encode('utf-8')

# # df_orders['id_pedido_mask'].head(100)

# # df = df_transactions.join(df_itens, on='codigo_produto_mask', how='left')
# # df = df_transactions.join(df_orders, lsuffix='id_pedido_mask', rsuffix='')
# df = df_transactions.merge(df_orders, on=['id_pedido_mask'], how='right')
# # df = df.join(df_orders, on='id_pedido_mask')

# df.head(100)

# %%
df = pd.read_sql('''SELECT 
	  transacoes.id_pedido_mask
	, transacoes.codigo_produto_mask
	, transacoes.id_usuario_mask
	, transacoes.brinde
	, transacoes.desconto
	, transacoes.frete
	, transacoes.quantidade
	, transacoes.receita
	, itens.familia
	, itens.peso_unitario
	, itens.setor
	, itens.subfamilia
	, pedidos.canal_marketing
	, pedidos.canal_venda
	, pedidos.contagempedidos
	, pedidos.forma_pagamento
	, pedidos.parcelas
	, pedidos.pedido_assinatura
	, pedidos.subcanal_venda
FROM transacoes transacoes
LEFT JOIN itens itens 
	ON transacoes.codigo_produto_mask = itens.codigo_produto_mask
LEFT JOIN pedidos pedidos
	ON transacoes.id_pedido_mask = pedidos.id_pedido_mask
GROUP BY 
	  transacoes.id_pedido_mask
	, transacoes.codigo_produto_mask
	, transacoes.id_usuario_mask
	, transacoes.brinde
	, transacoes.desconto
	, transacoes.frete
	, transacoes.quantidade
	, transacoes.receita
	, itens.familia
	, itens.peso_unitario
	, itens.setor
	, itens.subfamilia
	, pedidos.canal_marketing
	, pedidos.canal_venda
	, pedidos.contagempedidos
	, pedidos.forma_pagamento
	, pedidos.parcelas
	, pedidos.pedido_assinatura
	, pedidos.subcanal_venda
	''', engine)

df.head()
# Out:
#                      id_pedido_mask               codigo_produto_mask  \
# 0  0000b0f8dd3cc7c5058fb8307a252227  a14be9847bb8f688c740c1f048524713
# 1  0000b0f8dd3cc7c5058fb8307a252227  ca224057b4d75afbf4058891a259927b
# 2  0005dc868fdc729a89aff2919c59eac3  31338c1a5e939a35dc15453d7e4945ac
# 3  0005dc868fdc729a89aff2919c59eac3  387f68acc1a60738763e8680718672ff
# 4  0005dc868fdc729a89aff2919c59eac3  70df5caad67925aa6085ae92936426f5
#
#                     id_usuario_mask  brinde  desconto  frete  quantidade  \
# 0  a1aa3c5157fbb01ccd7960415e971fe4       0      0.00    0.0           1
# 1  a1aa3c5157fbb01ccd7960415e971fe4       0      0.00    0.0           2
# 2  8e6e06a58f303366beafb4b5ad924118       0     11.99    0.0           1
# 3  8e6e06a58f303366beafb4b5ad924118       0     19.16    0.0           4
# 4  8e6e06a58f303366beafb4b5ad924118       0     11.69    0.0           1
#
#    receita    familia  peso_unitario                 setor  \
# 0   110.90  Cachorros         16.800             Alimentos
# 1    16.84  Cachorros          0.010  Medicina e Bem Estar
# 2   107.91  Cachorros          0.235            Acessórios
# 3   172.44      Gatos         12.550      Higiene e Beleza
# 4   105.21      Gatos         10.100             Alimentos
#
#                subfamilia                   canal_marketing  \
# 0              Ração Seca  9db6d32a7901332471c3d304cf0a9a58
# 1              Vermífugos  9db6d32a7901332471c3d304cf0a9a58
# 2  Acessórios para Carros  decc1eab6d0751fcb2d8e41a2ffeb55a
# 3     Areias e Granulados  decc1eab6d0751fcb2d8e41a2ffeb55a
# 4              Ração Seca  decc1eab6d0751fcb2d8e41a2ffeb55a
#
#                         canal_venda contagempedidos          forma_pagamento  \
# 0  15bbb9d0bbf25e8d2978de1168c749dc              18  Cartão de Crédito Total
# 1  15bbb9d0bbf25e8d2978de1168c749dc              18  Cartão de Crédito Total
# 2  a564de63c2d0da68cf47586ee05984d7              35  Cartão de Crédito Total
# 3  a564de63c2d0da68cf47586ee05984d7              35  Cartão de Crédito Total
# 4  a564de63c2d0da68cf47586ee05984d7              35  Cartão de Crédito Total
#
#   parcelas  pedido_assinatura                    subcanal_venda
# 0        3                  0  b2c79ad7dcf03ba266dc0885e1266675
# 1        3                  0  b2c79ad7dcf03ba266dc0885e1266675
# 2        3                  1  6ab241effd5d8dd6ecdd79cba1ac174a
# 3        3                  1  6ab241effd5d8dd6ecdd79cba1ac174a
# 4        3                  1  6ab241effd5d8dd6ecdd79cba1ac174a

# %% [markdown]
# Agora, entendendo um pouco as categorias, em especial sobre a Família do produto. Se existe alguma prevalência entre produtos por tipo de animal doméstico.

# %%
plt.figure(figsize=(20,8))
sns.countplot(x='familia', data=df, order=df['familia'].value_counts().index)

# %% [markdown]
# **Pontos Importantes:** <br>
#     1. Obviamente, os animais domésticos são os mais presentes nos pedidos e produtos. Vindo primeiro Cachorros e depois Gatos; <br>
#     2. Temos outras cateogorias além de animais como as Private Label ou Acessórios. Seria importante entender se é proposital ou se faz sentido juntar categoria de produtos com o tipo de animal que irá consumir aquele produto.
#
# Agora, aprofundando por setor e entendendo mais alguns detalhes sobre receita com outras variáveis:

# %%
df_sector = pd.read_sql('''
    SELECT 
          setor
        , CAST(SUM(receita) AS decimal(10, 2)) AS receita_total
        , COUNT(DISTINCT id_usuario_mask) AS pedidos_unicos
        , CAST(SUM(receita) AS decimal(10, 2)) / COUNT(DISTINCT id_usuario_mask) AS ticket_medio
		, CAST(SUM(desconto) AS decimal(10, 2)) / COUNT(DISTINCT id_usuario_mask)  AS desconto_por_pedido
    FROM (
    SELECT 
        transacoes.id_pedido_mask
        , transacoes.codigo_produto_mask
        , transacoes.id_usuario_mask
        , transacoes.brinde
        , transacoes.desconto
        , transacoes.frete
        , transacoes.quantidade
        , transacoes.receita
        , itens.familia
        , itens.peso_unitario
        , itens.setor
        , itens.subfamilia
        , pedidos.canal_marketing
        , pedidos.canal_venda
        , pedidos.contagempedidos
        , pedidos.forma_pagamento
        , pedidos.parcelas
        , pedidos.pedido_assinatura
        , pedidos.subcanal_venda
    FROM transacoes transacoes
    LEFT JOIN pedidos pedidos
        ON transacoes.id_pedido_mask = pedidos.id_pedido_mask
    LEFT JOIN itens itens 
        ON transacoes.codigo_produto_mask = itens.codigo_produto_mask
    GROUP BY 
        transacoes.id_pedido_mask
        , transacoes.codigo_produto_mask
        , transacoes.id_usuario_mask
        , transacoes.brinde
        , transacoes.desconto
        , transacoes.frete
        , transacoes.quantidade
        , transacoes.receita
        , itens.familia
        , itens.peso_unitario
        , itens.setor
        , itens.subfamilia
        , pedidos.canal_marketing
        , pedidos.canal_venda
        , pedidos.contagempedidos
        , pedidos.forma_pagamento
        , pedidos.parcelas
        , pedidos.pedido_assinatura
        , pedidos.subcanal_venda
    )
    GROUP BY setor
    ORDER BY receita_total DESC
	''', engine)

df_sector.style.background_gradient(cmap='Purples')
# Out:
# <style  type="text/css" >
#     #T_844058bc_7f06_11ea_a330_937192ecb255row0_col1 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row0_col2 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row0_col3 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row0_col4 {
#             background-color:  #bdbedc;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row1_col1 {
#             background-color:  #dfdfed;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row1_col2 {
#             background-color:  #b9b9da;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row1_col3 {
#             background-color:  #8e8bc1;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row1_col4 {
#             background-color:  #e9e8f2;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row2_col1 {
#             background-color:  #e2e1ef;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row2_col2 {
#             background-color:  #928fc3;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row2_col3 {
#             background-color:  #bebedd;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row2_col4 {
#             background-color:  #f0eef5;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row3_col1 {
#             background-color:  #f3f2f8;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row3_col2 {
#             background-color:  #e3e2ef;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row3_col3 {
#             background-color:  #b3b3d6;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row3_col4 {
#             background-color:  #f3f1f7;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row4_col1 {
#             background-color:  #f8f7fa;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row4_col2 {
#             background-color:  #e8e6f2;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row4_col3 {
#             background-color:  #dedded;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row4_col4 {
#             background-color:  #f8f7fb;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row5_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row5_col2 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row5_col3 {
#             background-color:  #f1eff6;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row5_col4 {
#             background-color:  #f5f4f9;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row6_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row6_col2 {
#             background-color:  #a7a4ce;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row6_col3 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row6_col4 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row7_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row7_col2 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row7_col3 {
#             background-color:  #f0eef6;
#             color:  #000000;
#         }    #T_844058bc_7f06_11ea_a330_937192ecb255row7_col4 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }</style><table id="T_844058bc_7f06_11ea_a330_937192ecb255" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >setor</th>        <th class="col_heading level0 col1" >receita_total</th>        <th class="col_heading level0 col2" >pedidos_unicos</th>        <th class="col_heading level0 col3" >ticket_medio</th>        <th class="col_heading level0 col4" >desconto_por_pedido</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_844058bc_7f06_11ea_a330_937192ecb255level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row0_col0" class="data row0 col0" >Alimentos</td>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row0_col1" class="data row0 col1" >8.4395e+06</td>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row0_col2" class="data row0 col2" >31551</td>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row0_col3" class="data row0 col3" >267.488</td>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row0_col4" class="data row0 col4" >24.7045</td>
#             </tr>
#             <tr>
#                         <th id="T_844058bc_7f06_11ea_a330_937192ecb255level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row1_col0" class="data row1 col0" >Medicina e Bem Estar</td>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row1_col1" class="data row1 col1" >1.8621e+06</td>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row1_col2" class="data row1 col2" >12298</td>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row1_col3" class="data row1 col3" >151.415</td>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row1_col4" class="data row1 col4" >11.9093</td>
#             </tr>
#             <tr>
#                         <th id="T_844058bc_7f06_11ea_a330_937192ecb255level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row2_col0" class="data row2 col0" >Higiene e Beleza</td>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row2_col1" class="data row2 col1" >1.7459e+06</td>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row2_col2" class="data row2 col2" >17375</td>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row2_col3" class="data row2 col3" >100.483</td>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row2_col4" class="data row2 col4" >9.32937</td>
#             </tr>
#             <tr>
#                         <th id="T_844058bc_7f06_11ea_a330_937192ecb255level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row3_col0" class="data row3 col0" >Acessórios</td>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row3_col1" class="data row3 col1" >699514</td>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row3_col2" class="data row3 col2" >6262</td>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row3_col3" class="data row3 col3" >111.708</td>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row3_col4" class="data row3 col4" >7.4843</td>
#             </tr>
#             <tr>
#                         <th id="T_844058bc_7f06_11ea_a330_937192ecb255level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_844058bc_7f06_11ea_a330_937192ecb255row4_col0" class="data row4 col0" >

# %% [markdown]
# Algumas observações importantes:
#     1. Os setores que trouxeram mais Receita Total e com maior Ticket Médio foram Alimentos com Medicina e Bem Estar.
#     2. Apesar de não ter tido uma venda expressiva, os itens Não Vendável apareceram em 14 mil pedidos únicos, ficando em terceiro lugar do setor que mais aparece em pedidos;
#     3. Outros pontos importantes do Não Vendável é que apesar de frequente nos pedidos, ele tem um baixíssimo ticket médio (o mais baixo de todos os setores), além de ter o maior Desconto por Pedido de qualquer outro setor!
#
# Agora teremos as mesmas coluna para avaliar os **canais de venda**:

# %%
df_sales = pd.read_sql('''
    SELECT 
          canal_venda
		, CAST(SUM(receita) AS decimal(10, 2)) AS receita_total
    FROM (
    SELECT 
        transacoes.id_pedido_mask
        , transacoes.codigo_produto_mask
        , transacoes.id_usuario_mask
        , transacoes.brinde
        , transacoes.desconto
        , transacoes.frete
        , transacoes.quantidade
        , transacoes.receita
        , itens.familia
        , itens.peso_unitario
        , itens.setor
        , itens.subfamilia
        , pedidos.canal_marketing
        , pedidos.canal_venda
        , pedidos.contagempedidos
        , pedidos.forma_pagamento
        , pedidos.parcelas
        , pedidos.pedido_assinatura
        , pedidos.subcanal_venda
    FROM transacoes transacoes
    LEFT JOIN pedidos pedidos
        ON transacoes.id_pedido_mask = pedidos.id_pedido_mask
    LEFT JOIN itens itens 
        ON transacoes.codigo_produto_mask = itens.codigo_produto_mask
    GROUP BY 
        transacoes.id_pedido_mask
        , transacoes.codigo_produto_mask
        , transacoes.id_usuario_mask
        , transacoes.brinde
        , transacoes.desconto
        , transacoes.frete
        , transacoes.quantidade
        , transacoes.receita
        , itens.familia
        , itens.peso_unitario
        , itens.setor
        , itens.subfamilia
        , pedidos.canal_marketing
        , pedidos.canal_venda
        , pedidos.contagempedidos
        , pedidos.forma_pagamento
        , pedidos.parcelas
        , pedidos.pedido_assinatura
        , pedidos.subcanal_venda
    )
    GROUP BY canal_venda
    ORDER BY receita_total DESC
	''', engine)

df_sales = df_sales[['receita_total', 'canal_venda']].set_index('canal_venda')
df_sales = df_sales[0:4].sort_values(by = "receita_total", ascending = True)

df_sales.plot.barh()
plt.title("Canais de Venda com Maior Receita Acumulada")
plt.xticks(rotation=0)
# Out:
# (array([      0., 1000000., 2000000., 3000000., 4000000., 5000000.,
#         6000000.]),
#  <a list of 7 Text major ticklabel objects>)

# %% [markdown]
# **Outros pontos importantes:** <br>
# 1. Os dois canais de venda estão empatados em receita totais; <br>
# 2. Mas os dois principais representam quase 85% de toda a receita dos pedidos.

# %% [markdown]
# ## Etapa 2: Entendimento das alavancas de receita
# Primeiro passo é compreender melhor a correlação para produzir insights úteis com relação a Receita. Por ser um dataframe com várias variáveis, foi usado  a correlação do pandas com método de Person para entender com relacionado são as variáveis (de maneira positiva ou negativa). Assim encontramos as principais relações primeiro e vamos explorando elas profundamente.

# %%
sns.heatmap(df.corr(method='pearson'), annot=True)
plt.show()

# %% [markdown]
# **Pontos Importantes:** <br>
#     1. Olhando o principal indicador que é receita, aquela variável que mais afeta positivamente a métrica é referente ao Peso Unitário, seguido de Frete; <br>
#     2. A métrica que mais afeta a receita negativamente é Brinde; <br>
#     3. Existe uma forte relação positiva entre Desconto e Brinde.
#
# Agora, explorando essas variáveis apenas visualmente:

# %%
sns.lmplot(x='receita', y='peso_unitario', data=df, fit_reg=True)

# %%
sns.lmplot(x='receita', y='brinde', data=df, fit_reg=True)

# %%
sns.lmplot(x='desconto', y='brinde', data=df, fit_reg=True)

# %%
sns.lmplot(x='receita', y='frete', data=df, fit_reg=True)

# %% [markdown]
# ## Etapa 3: Recomendação
# LOREM IPSUM

# %% [markdown]
# ## Etapa 4: Próximos passos
# LOREM IPSUM
